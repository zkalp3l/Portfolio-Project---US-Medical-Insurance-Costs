# %% [markdown]
# # U.S. Medical Insurance Costs

# %%
import csv

# %%
# Load csv reader into column lists

ages = []
genders = []
bmis = []
childrens = []
smokers = []
regions = []
charges = []
#costsBySmoker = {}


with open('insurance.csv') as fh:
    fData = csv.DictReader(fh)
    #print(dict(fData[0]))
    #print( fData.readlines() )
    #print( fData['age'] )
    for row in fData:
        #print(row)
        #print(row['smoker'])
        ages.append( int( row['age']))
        genders.append(row['sex'])
        bmis.append( float(row['bmi']))
        childrens.append( int( row['children']))
        smokers.append(row['smoker'])
        regions.append(row['region'])
        charges.append(row['charges'])
        #costsBySmoker['smoker']=

# %%
#print( bmis, childrens, smokers )

# %%
sum( bmis ) / len( bmis )
# Out:
# 30.663396860986538

# %%
import statistics as stats

# %%
stats.mean(bmis)
# Out:
# 30.66339686098655

# %%
## freq the reqions

#print ( regions )
#print ( enumerate( regions ))
#list( enumerate( regions))
# from https://stackoverflow.com/questions/40553332/finding-frequency-distribution-of-a-list-of-numbers-in-python
def freq(lst):
    d = {}
    for i in lst:
        if d.get(i):
            d[i] += 1
        else:
            d[i] = 1
    return d

# %%
freq(regions)
#freq(genders)
# Out:
# {'southwest': 325, 'southeast': 364, 'northwest': 325, 'northeast': 324}

# %%
#ZIP() is amazing for this

#zip smoker list with charges list

smokerCosts = zip( smokers, charges )

# %%
#print( smokerCosts )

# %%
#print( dict( smokerCosts) )

# %%
bmisByGender = zip( genders, bmis)

# %%
#print( dict( bmisByGender) )

# %%
costsByRegion = zip( regions, charges)

# %%
#print( dict(costsByRegion))

# %%
def aggByListValue(lst):
    d = {}
    for i in lst:
        if d.get(i):
            d[i] += 1
        else:
            d[i] = 1
    return d
